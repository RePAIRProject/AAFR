# %%
from runner import experiment
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
my_expirments = experiment("conf1.yaml")
# Out:
# {'data': [['data_test\\group8_1\\RPf_00059_gt.ply', 'data_test\\group8_1\\RPf_00060_gt.ply']], 'rotation': {'x': [0.0], 'y': [1.14], 'z': [0.6]}, 'translation': {'x': [0.0], 'y': [10.0], 'z': [15.0]}, 'piplines': [{'name': ['pipline_1'], 'para1': [15.0], 'para2': array([78.4970409 , 35.50711408, 54.35018694]), 'para3': [1, 10, 3], 'para4': array([1., 4., 7.])}], 'tests': [['ICP_test']], 'evaluation': ['rms', 'new_eval']}

# %%
my_expirments.conf

# %%
my_expirments.run()

# %%
my_expirments.results
