# %%
from runner import test
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
import numpy as np

#objects
Obj1_url = "data_test/pairwise/repair_group15_pair2/RPf_00105_gt.ply"
Obj2_url =  "data_test/pairwise/repair_group15_pair2/RPf_00107_gt.ply"

#Before Evaluate do a Rotation and translation of
init_R_T = [( 0, 0, 0),( 0.1, 0.1, 0.1)]


#pipline name and pipline parameters
pipline_name = "pipline_1"

N = 15
t1 = 2
t2 = 2
t3 = 2


#threshold for corner
thre = 0.95

pipline_variables = (N, t1, t2, t3, thre)

#test
test_name = "ICP_test"

# eval 

eval_list = ["rms"]

# %%
test1 = test(Obj2_url, Obj1_url, init_R_T, pipline_name, pipline_variables, test_name, eval_list, show_results = True, save_results=True)

# %%
test1.run()
# Out:
# start
# starting init
# starting threshold
# create graph
# my radius is :  0.049790070497722244
# 100%|████████████████████████████████████████████████████████████████████████████| 6281/6281 [00:04<00:00, 1563.24it/s]
# After graph 6124
# After Pruning 1442
# start
# starting init
# starting threshold
# create graph
# my radius is :  0.07894059726986122
# 100%|████████████████████████████████████████████████████████████████████████████| 3999/3999 [00:02<00:00, 1610.92it/s]
# After graph 3677
# After Pruning 666
# {'R_error': 0.3340115903001268, 'T_error': 0.7218866036660085}
