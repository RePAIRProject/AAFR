# %%
import helper

# %%
import pipline_modules.pipline_1 as pipeline

#Before Evaluate do a Rotation and translation of
init_R_T = [( 0 , 0 , 0),( -0.2, 0, 0 )]


#pipline name and pipline parameters
pipline_name = "pipline_1"

N = 15
t1 = 5
t2 = 5
t3 = 5


#threshold for corner
thre = 0.90

pipline_variables = (N, t1, t2, t3, thre)

# %%
Obj1 = pipeline.run("data_test/pairwise/repair_group15_pair1/RPf_00105_gt.ply" ,pipline_variables)

# %%
Obj1.pruned_graph

# %%
import helper

# %%
my_obj = Obj1.pcd_original

# %%
def find_cycles(Graph):
    visited = set()
    cycles = []
    stack = [[list(Graph.nodes)[0]]]
    parent = None
    while stack:
        path = stack.pop(-1)
        last_node = path[-1]
        # check that the node is not visited before if it is visited then it is a cycle
        if last_node in visited:
            cycles.append((path,last_node))
            continue 
        visited.add(last_node)
        nghs = Graph.neighbors(last_node)
        for node in nghs:
            if parent and parent == last_node:
                continue
            stack.append(path+[node])
    filtered_cycles = []
    for cycle,node in cycles:
        path = []
        counter = 0
        for n in cycle:
            if node == n:
                counter = 1
                
            if counter:
                path.append(n)
            else:
                continue
        filtered_cycles.append((path,len(path)))
    return filtered_cycles

# %%
cycles = find_cycles(Obj1.pruned_graph)

# %%
sorted_cycles = sorted(cycles,key = lambda x:x[1],reverse=True)

# %%
sorted_cycles

# %%
from copy import copy
new_obj = copy(Obj1.pcd)

# %%
a,b = sorted_cycles[0]

# %%
import open3d as o3d
import numpy as np

for cycle,length in sorted_cycles[0:10]:
    colors = [(0,255,0) for _ in my_obj.points]
    points = cycle
    for point in points:
        print(point)
        colors[point] = (255,0,0)

    my_obj.colors = o3d.utility.Vector3dVector(np.asarray(colors).astype(np.float) / 255.0)
    o3d.visualization.draw_geometries([my_obj])

# %% [markdown]
# <h1>Check flat surfaces (Get rotation for it)</h1>

# %%
import helper
import pipline_modules.pipline_1 as pipeline

#Before Evaluate do a Rotation and translation of
init_R_T = [( 0 , 0 , 0),( -0.2, 0, 0 )]


#pipline name and pipline parameters
pipline_name = "pipline_1"

N = 15
t1 = 5
t2 = 5
t3 = 5


#threshold for corner
thre = 0.80

pipline_variables = (N, t1, t2, t3, thre)

# %%
from copy import copy
import helper
import numpy as np
from Fragment import FeatureLines
from tqdm import tqdm
import open3d as o3d
import numpy as np

print("start")

Obj_url = "data_test/pairwise/repair_group8_pair1/RPf_00060_gt.ply"

Obj = FeatureLines(Obj_url,voxel_size=30000)
# print("Size :",len(Obj.pcd.points))

print("starting init")
Obj.init(int(N))

# %%
points = np.asarray(Obj.pcd.points)
centroid = points.mean()
points_vectors = points - centroid

# %%
points_vectors

# %%
from numpy.linalg import norm
def cal_cos(p_vec,q_vecs):
    p_vecs = np.repeat(p_vec.reshape(1,3),len(q_vecs),axis=0)
    p_dot_q = (p_vecs * q_vecs).sum(axis=1)
    p_norms = np.sqrt((p_vecs*p_vecs).sum(axis=1))
    q_norms = np.sqrt((q_vecs*q_vecs).sum(axis=1))
    cos_sim = p_dot_q / (p_norms*q_norms)
    return np.mean(cos_sim)

# %%
cal_cos(points_vectors[0],points_vectors[0:10])

# %%
from scipy import spatial
pcd_tree = o3d.geometry.KDTreeFlann(Obj.pcd)
sim_results = []
for i in range(len(Obj.pcd.points)):
        point = Obj.pcd.points[i]
        p_vector = points_vectors[i]
        [k, idx, _] = pcd_tree.search_knn_vector_3d(point, 5)
        q_vectors = np.asarray(points_vectors).take(idx,axis=0)
        result = cal_cos(p_vector, q_vectors)
        sim_results.append((result,(p_vector[0]%255,p_vector[1]%255,p_vector[2]%255)))

# %%
sim_results

# %%
import open3d as o3d
import numpy as np
colors = [(0,255,0) for _ in Obj.pcd.points]
for i,point in enumerate(Obj.pcd.points):
    colors[i] = sim_results[i][1]

Obj.pcd.colors = o3d.utility.Vector3dVector(np.asarray(colors).astype(np.float) / 255.0)
o3d.visualization.draw_geometries([Obj.pcd])

# %% [markdown]
# <h1>New Trial to get sides

# %%
import helper
import pipline_modules.pipline_1 as pipeline
from Fragment import FeatureLines 
import numpy as np
#Before Evaluate do a Rotation and translation of
init_R_T = [( 0 , 0 , 0),( -0.2, 0, 0 )]


#pipline name and pipline parameters
pipline_name = "pipline_1"

N = 15
t1 = 2
t2 = 100
t3 = 100

Obj_url = "data_test/pairwise/repair_group15_pair5/RPf_00099_gt.ply"
#threshold for corner
thre = 0.985

pipline_variables = (N, t1, t2, t3, thre)

# %%
(N, shortest_cycle_length, smallest_isolated_island_length, shortest_allowed_branch_length, thre) = pipline_variables

print("start")
Obj = FeatureLines(Obj_url,voxel_size=30000)
# print("Size :",len(Obj.pcd.points))
print("starting init")
Obj.init(int(N))

# print("Size valid :",len(valid))

shortest_cycle_length = np.sqrt(len(Obj.pcd.points))//shortest_cycle_length
smallest_isolated_island_length = np.sqrt(len(Obj.pcd.points))//smallest_isolated_island_length
shortest_allowed_branch_length = np.sqrt(len(Obj.pcd.points))//shortest_allowed_branch_length

isolated_islands_pruned_graph, F_lines, isolated_islands = helper.create_graph(Obj, \
shortest_cycle_length, smallest_isolated_island_length)
print("After graph",len([point for branch in F_lines for point in branch]))
pruned_graph_original, removed_nodes, valid_nodes = helper.prune_branches(F_lines,isolated_islands_pruned_graph,\
shortest_allowed_branch_length)
print("After Pruning",len([node for branch in valid_nodes for node in branch]))
# Out:
# start
# starting init
# my radius is :  0.021194888087011223
# 326136
# After graph 29822
# After Pruning 29822

# %%
from copy import copy
tmp_Obj = copy(Obj)
tmp_Obj.pcd = copy(Obj.pcd)

N = 15
t1 = 0.1
t2 = 1
t3 = 0.1
pipline_variables = (N, t1, t2, t3, thre)
(N, shortest_cycle_length, smallest_isolated_island_length, shortest_allowed_branch_length, thre) = pipline_variables
# print("Size valid :",len(valid))
valid = []
for idx,val in enumerate(tmp_Obj.w_co):
    if val<0.985:
        valid.append(idx)
print(len(valid))
shortest_cycle_length = np.sqrt(len(valid))//shortest_cycle_length
smallest_isolated_island_length = np.sqrt(len(valid))//smallest_isolated_island_length
shortest_allowed_branch_length = np.sqrt(len(valid))//shortest_allowed_branch_length
print("shortest_allowed_branch_length",shortest_allowed_branch_length)
print("smallest_isolated_island_length",smallest_isolated_island_length)
print("shortest_cycle_length",shortest_cycle_length)
isolated_islands_pruned_graph, F_lines, isolated_islands = helper.create_graph(tmp_Obj, \
shortest_cycle_length, smallest_isolated_island_length,mask=valid,radius=None)
print("After graph",len([point for branch in F_lines for point in branch]))
pruned_graph, removed_nodes, valid_nodes = helper.prune_branches(F_lines,isolated_islands_pruned_graph,\
shortest_allowed_branch_length)
print("After Pruning",len([node for branch in valid_nodes for node in branch]))
# Out:
# 11737
# shortest_allowed_branch_length 1083.0
# smallest_isolated_island_length 108.0
# shortest_cycle_length 1083.0
# my radius is :  0.026707467029473495
# 163579
# After graph 11574
# After Pruning 1498

# %% [markdown]
# <h3>normal borders as before

# %%
border_nodes = [node for branch in valid_nodes for node in branch]

# %%
import open3d as o3d
import numpy as np
colors = [(0,255,0) for _ in Obj.pcd.points]
for point in border_nodes:
    colors[point] = (255,0,0)
Obj.pcd.colors = o3d.utility.Vector3dVector(np.asarray(colors).astype(np.float) / 255.0)
o3d.visualization.draw_geometries([Obj.pcd])
# Out:
# C:\Users\alial\AppData\Local\Temp\ipykernel_17824\18278585.py:6: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Obj.pcd.colors = o3d.utility.Vector3dVector(np.asarray(colors).astype(np.float) / 255.0)

# %% [markdown]
# <h3> segment sides using DFS

# %%
without_dilated_faces = get_sides(pruned_graph_original, border_nodes)

# %%
import open3d as o3d
import numpy as np
colors = [(0,255,0) for _ in Obj.pcd.points]
for size,face in without_dilated_faces:
    color = tuple(random.choices(range(256), k=3))
    for point in face:
        colors[point] = color
Obj.pcd.colors = o3d.utility.Vector3dVector(np.asarray(colors).astype(np.float) / 255.0)
o3d.visualization.draw_geometries([Obj.pcd])
# Out:
# C:\Users\alial\AppData\Local\Temp\ipykernel_17824\453507087.py:8: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Obj.pcd.colors = o3d.utility.Vector3dVector(np.asarray(colors).astype(np.float) / 255.0)

# %% [markdown]
# <h3> Dilate borders

# %%
my_obj = copy(Obj)
my_obj.pcd = copy(Obj.pcd)

# %%
def dilate_border(my_obj,border,size):
    tmp_Obj = copy(my_obj)
    tmp_Obj.pcd = copy(my_obj.pcd)
    pcd_tree = o3d.geometry.KDTreeFlann(tmp_Obj.pcd)
    w_co = copy(tmp_Obj.w_co)
    new_borders = []
    for idx in border:
        point = Obj.pcd.points[idx]
        [k, idx, _] = pcd_tree.search_radius_vector_3d(point,size)
        new_borders.extend(idx)
    return new_borders

# %%
dilated_border = dilate_border(Obj,border_nodes,0.01)

# %%
import open3d as o3d
import numpy as np
colors = [(0,255,0) for _ in Obj.pcd.points]
for point in dilated_border:
    colors[point] = (255,0,0)
Obj.pcd.colors = o3d.utility.Vector3dVector(np.asarray(colors).astype(np.float) / 255.0)
o3d.visualization.draw_geometries([Obj.pcd])
# Out:
# C:\Users\alial\AppData\Local\Temp\ipykernel_17824\1173355505.py:6: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Obj.pcd.colors = o3d.utility.Vector3dVector(np.asarray(colors).astype(np.float) / 255.0)

# %% [markdown]
# <h3> segment again using dilated borders

# %%
import random
def get_sides(Graph, borders):
    faces = []
    all_visited = set()
    nodes = list(Graph.nodes)
    while len(nodes):
        random_point = nodes.pop(0)
        while random_point in all_visited:
            if not len(nodes):
                sorted_faces = sorted(faces,key = lambda key:key[0], reverse = True)
                return sorted_faces[:10]
            random_point = nodes.pop(0)
       
        queue = [random_point]
        visited = set()
        while len(queue):
            point = queue.pop(0)
            if point not in visited:
                visited.add(point)
                all_visited.add(point)
                neighbors = Graph.neighbors(point)
                for neighbor in neighbors:
                    all_visited.add(neighbor)
                    if neighbor not in borders:
                        queue.append(neighbor)
        faces.append((len(visited),visited))
    sorted_faces = sorted(faces,key = lambda key:key[0], reverse = True)
    return sorted_faces[:20]

# %%
dilated_faces = get_sides(pruned_graph_original, dilated_border)

# %%
import open3d as o3d
import numpy as np
colors = [(0,255,0) for _ in Obj.pcd.points]
for size,face in dilated_faces:
    color = tuple(random.choices(range(256), k=3))
    for point in face:
        colors[point] = color
Obj.pcd.colors = o3d.utility.Vector3dVector(np.asarray(colors).astype(np.float) / 255.0)
o3d.visualization.draw_geometries([Obj.pcd])
# Out:
# C:\Users\alial\AppData\Local\Temp\ipykernel_17824\289554337.py:8: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Obj.pcd.colors = o3d.utility.Vector3dVector(np.asarray(colors).astype(np.float) / 255.0)

# %% [markdown]
# <h3> Expand segments by using KNN

# %%
node_face = {}
face_nodes = []
for idx,(_,face) in enumerate(dilated_faces):
    for node in face:
        node_face[node] = idx
    face_nodes.append(face)
for key,value in node_face.items():
    if value>=10:
        print(value)
        
all_dilated = [node for  _,face in dilated_faces for node in face]
all_dilated.extend([node for node in dilated_border])

# %%
all_dilated
# Out:
# [2,
#  10,
#  11,
#  25,
#  30,
#  33,
#  37,
#  43,
#  56,
#  60,
#  64,
#  67,
#  72,
#  78,
#  79,
#  85,
#  87,
#  90,
#  101,
#  103,
#  104,
#  109,
#  113,
#  117,
#  123,
#  124,
#  125,
#  126,
#  130,
#  132,
#  133,
#  145,
#  151,
#  153,
#  154,
#  172,
#  174,
#  177,
#  178,
#  183,
#  186,
#  189,
#  196,
#  198,
#  201,
#  202,
#  206,
#  208,
#  209,
#  211,
#  222,
#  242,
#  245,
#  248,
#  253,
#  256,
#  261,
#  263,
#  264,
#  267,
#  270,
#  271,
#  272,
#  279,
#  284,
#  285,
#  293,
#  294,
#  298,
#  302,
#  306,
#  308,
#  315,
#  317,
#  319,
#  331,
#  336,
#  344,
#  346,
#  350,
#  353,
#  365,
#  368,
#  377,
#  380,
#  383,
#  397,
#  410,
#  417,
#  423,
#  424,
#  425,
#  440,
#  451,
#  461,
#  462,
#  464,
#  470,
#  481,
#  482,
#  483,
#  489,
#  495,
#  502,
#  503,
#  505,
#  508,
#  517,
#  519,
#  530,
#  535,
#  536,
#  537,
#  538,
#  541,
#  543,
#  551,
#  552,
#  555,
#  558,
#  561,
#  563,
#  567,
#  570,
#  572,
#  575,
#  578,
#  579,
#  580,
#  584,
#  593,
#  594,
#  600,
#  605,
#  608,
#  613,
#  617,
#  622,
#  623,
#  625,
#  628,
#  630,
#  636,
#  637,
#  639,
#  643,
#  646,
#  666,
#  668,
#  670,
#  673,
#  678,
#  685,
#  686,
#  688,
#  690,
#  693,
#  700,
#  707,
#  710,
#  711,
#  716,
#  723,
#  727,
#  732,
#  737,
#  738,
#  739,
#  750,
#  751,
#  752,
#  755,
#  759,
#  775,
#  779,
#  781,
#  782,
#  785,
#  790,
#  799,
#  802,
#  813,
#  815,
#  822,
#  823,
#  824,
#  830,
#  832,
#  840,
#  850,
#  853,
#  855,
#  864,
#  866,
#  867,
#  868,
#  869,
#  873,
#  877,
#  885,
#  886,
#  890,
#  892,
#  899,
#  904,
#  910,
#  917,
#  927,
#  929,
#  934,
#  951,
#  957,
#  980,
#  984,
#  987,
#  992,
#  996,
#  998,
#  1001,
#  1012,
#  1015,
#  1026,
#  1029,
#  1031,
#  1034,
#  1036,
#  1038,
#  1044,
#  1053,
#  1057,
#  1059,
#  1060,
#  1064,
#  1067,
#  1072,
#  1073,
#  1079,
#  1080,
#  1081,
#  1084,
#  1086,
#  1087,
#  1094,
#  1104,
#  1106,
#  1113,
#  1120,
#  1124,
#  1142,
#  1148,
#  1149,
#  1150,
#  1152,
#  1154,
#  1156,
#  1160,
#  1166,
#  1168,
#  1175,
#  1183,
#  1184,
#  1187,
#  1189,
#  1200,
#  1207,
#  1212,
#  1222,
#  1224,
#  1229,
#  1236,
#  1237,
#  1239,
#  1243,
#  1256,
#  1259,
#  1267,
#  1268,
#  1273,
#  1274,
#  1278,
#  1279,
#  1281,
#  1285,
#  1288,
#  1289,
#  1292,
#  1293,
#  1297,
#  1301,
#  1310,
#  1314,
#  1319,
#  1326,
#  1327,
#  1329,
#  1331,
#  1333,
#  1334,
#  1336,
#  1339,
#  1341,
#  1344,
#  1345,
#  1346,
#  1356,
#  1357,
#  1360,
#  1363,
#  1366,
#  1367,
#  1370,
#  1381,
#  1383,
#  1384,
#  1388,
#  1389,
#  1392,
#  1393,
#  1397,
#  1406,
#  1413,
#  1427,
#  1435,
#  1439,
#  1444,
#  1446,
#  1447,
#  1451,
#  1462,
#  1463,
#  1465,
#  1467,
#  1469,
#  1470,
#  1474,
#  1476,
#  1477,
#  1481,
#  1486,
#  1489,
#  1495,
#  1502,
#  1510,
#  1515,
#  1521,
#  1522,
#  1527,
#  1529,
#  1530,
#  1532,
#  1533,
#  1534,
#  1537,
#  1540,
#  1544,
#  1550,
#  1552,
#  1569,
#  1578,
#  1581,
#  1582,
#  1583,
#  1587,
#  1593,
#  1596,
#  1598,
#  1600,
#  1602,
#  1603,
#  1606,
#  1608,
#  1615,
#  1621,
#  1625,
#  1629,
#  1631,
#  1641,
#  1643,
#  1645,
#  1647,
#  1649,
#  1654,
#  1655,
#  1656,
#  1663,
#  1668,
#  1669,
#  1677,
#  1680,
#  1681,
#  1690,
#  1691,
#  1695,
#  1697,
#  1700,
#  1702,
#  1704,
#  1719,
#  1729,
#  1730,
#  1737,
#  1748,
#  1752,
#  1763,
#  1765,
#  1766,
#  1768,
#  1770,
#  1771,
#  1772,
#  1774,
#  1776,
#  1778,
#  1779,
#  1780,
#  1787,
#  1793,
#  1800,
#  1801,
#  1805,
#  1807,
#  1811,
#  1823,
#  1824,
#  1826,
#  1828,
#  1830,
#  1831,
#  1834,
#  1836,
#  1842,
#  1847,
#  1850,
#  1855,
#  1859,
#  1860,
#  1866,
#  1867,
#  1875,
#  1881,
#  1885,
#  1886,
#  1887,
#  1890,
#  1891,
#  1894,
#  1898,
#  1901,
#  1910,
#  1914,
#  1929,
#  1934,
#  1941,
#  1943,
#  1951,
#  1965,
#  1970,
#  1971,
#  1978,
#  1981,
#  1986,
#  1997,
#  2001,
#  2009,
#  2011,
#  2012,
#  2014,
#  2028,
#  2031,
#  2032,
#  2041,
#  2047,
#  2059,
#  2060,
#  2064,
#  2066,
#  2073,
#  2078,
#  2083,
#  2089,
#  2093,
#  2097,
#  2101,
#  2114,
#  2115,
#  2117,
#  2123,
#  2125,
#  2128,
#  2133,
#  2141,
#  2149,
#  2151,
#  2160,
#  2161,
#  2162,
#  2167,
#  2176,
#  2181,
#  2183,
#  2184,
#  2187,
#  2190,
#  2192,
#  2193,
#  2197,
#  2198,
#  2200,
#  2202,
#  2210,
#  2212,
#  2219,
#  2221,
#  2222,
#  2224,
#  2234,
#  2241,
#  2245,
#  2246,
#  2249,
#  2252,
#  2256,
#  2259,
#  2260,
#  2261,
#  2262,
#  2266,
#  2267,
#  2268,
#  2275,
#  2283,
#  2284,
#  2286,
#  2293,
#  2298,
#  2299,
#  2302,
#  2306,
#  2308,
#  2310,
#  2317,
#  2325,
#  2326,
#  2331,
#  2332,
#  2333,
#  2336,
#  2341,
#  2344,
#  2350,
#  2361,
#  2364,
#  2365,
#  2370,
#  2375,
#  2376,
#  2379,
#  2384,
#  2386,
#  2387,
#  2392,
#  2393,
#  2403,
#  2405,
#  2406,
#  2410,
#  2423,
#  2430,
#  2435,
#  2436,
#  2437,
#  2439,
#  2446,
#  2448,
#  2455,
#  2456,
#  2457,
#  2460,
#  2463,
#  2465,
#  2467,
#  2468,
#  2472,
#  2477,
#  2483,
#  2494,
#  2495,
#  2497,
#  2500,
#  2508,
#  2510,
#  2519,
#  2528,
#  2532,
#  2533,
#  2535,
#  2539,
#  2540,
#  2542,
#  2549,
#  2553,
#  2555,
#  2556,
#  2562,
#  2566,
#  2571,
#  2577,
#  2578,
#  2580,
#  2582,
#  2584,
#  2586,
#  2589,
#  2594,
#  2595,
#  2601,
#  2602,
#  2603,
#  2607,
#  2618,
#  2619,
#  2621,
#  2622,
#  2624,
#  2629,
#  2630,
#  2636,
#  2638,
#  2639,
#  2645,
#  2649,
#  2653,
#  2658,
#  2659,
#  2660,
#  2664,
#  2673,
#  2682,
#  2685,
#  2687,
#  2695,
#  2696,
#  2697,
#  2698,
#  2699,
#  2713,
#  2714,
#  2719,
#  2723,
#  2724,
#  2731,
#  2735,
#  2740,
#  2745,
#  2757,
#  2764,
#  2765,
#  2775,
#  2783,
#  2789,
#  2790,
#  2793,
#  2811,
#  2814,
#  2818,
#  2819,
#  2832,
#  2838,
#  2840,
#  2846,
#  2847,
#  2848,
#  2852,
#  2854,
#  2858,
#  2860,
#  2863,
#  2864,
#  2868,
#  2869,
#  2874,
#  2875,
#  2876,
#  2879,
#  2882,
#  2889,
#  2891,
#  2892,
#  2896,
#  2898,
#  2899,
#  2901,
#  2907,
#  2913,
#  2915,
#  2921,
#  2937,
#  2940,
#  2947,
#  2953,
#  2955,
#  2957,
#  2967,
#  2970,
#  2971,
#  2972,
#  2978,
#  2982,
#  2994,
#  3000,
#  3001,
#  3005,
#  3023,
#  3033,
#  3035,
#  3036,
#  3042,
#  3043,
#  3048,
#  3049,
#  3053,
#  3056,
#  3059,
#  3066,
#  3069,
#  3073,
#  3075,
#  3081,
#  3087,
#  3092,
#  3095,
#  3097,
#  3099,
#  3106,
#  3109,
#  3110,
#  3121,
#  3124,
#  3126,
#  3128,
#  3129,
#  3130,
#  3131,
#  3132,
#  3134,
#  3135,
#  3136,
#  3137,
#  3155,
#  3160,
#  3161,
#  3165,
#  3173,
#  3181,
#  3189,
#  3197,
#  3198,
#  3199,
#  3201,
#  3203,
#  3210,
#  3213,
#  3214,
#  3218,
#  3219,
#  3221,
#  3226,
#  3237,
#  3239,
#  3240,
#  3241,
#  3242,
#  3243,
#  3245,
#  3247,
#  3248,
#  3250,
#  3253,
#  3254,
#  3259,
#  3263,
#  3265,
#  3266,
#  3268,
#  3270,
#  3272,
#  3273,
#  3275,
#  3279,
#  3286,
#  3287,
#  3298,
#  3302,
#  3306,
#  3307,
#  3308,
#  3311,
#  3332,
#  3336,
#  3340,
#  3342,
#  3343,
#  3345,
#  3350,
#  3353,
#  3357,
#  3358,
#  3362,
#  3369,
#  3378,
#  3380,
#  3381,
#  3387,
#  3395,
#  3396,
#  3399,
#  3400,
#  3403,
#  3410,
#  3413,
#  3415,
#  3417,
#  3425,
#  3429,
#  3434,
#  3442,
#  3454,
#  3459,
#  3469,
#  3473,
#  3478,
#  3482,
#  3483,
#  3488,
#  3489,
#  3497,
#  3509,
#  3518,
#  3524,
#  3525,
#  3529,
#  3549,
#  3552,
#  3557,
#  3560,
#  3563,
#  3567,
#  3571,
#  3572,
#  3574,
#  3578,
#  3583,
#  3585,
#  3588,
#  3594,
#  3595,
#  3597,
#  3603,
#  3610,
#  3611,
#  3616,
#  3617,
#  3626,
#  3627,
#  3639,
#  3642,
#  3645,
#  3651,
#  3659,
#  3660,
#  3661,
#  3670,
#  3672,
#  3675,
#  3677,
#  3678,
#  3695,
#  3701,
#  3713,
#  3720,
#  3736,
#  3737,
#  3745,
#  3754,
#  3763,
#  3766,
#  3767,
#  3770,
#  3775,
#  3781,
#  3783,
#  3784,
#  3787,
#  3790,
#  3793,
#  3797,
#  3798,
#  3800,
#  3803,
#  3804,
#  3808,
#  3811,
#  3820,
#  3822,
#  3829,
#  3836,
#  3841,
#  3853,
#  3854,
#  3858,
#  3863,
#  3864,
#  3865,
#  3868,
#  3871,
#  3874,
#  3878,
#  3885,
#  3886,
#  3888,
#  3889,
#  3892,
#  3897,
#  3904,
#  3909,
#  3913,
#  3915,
#  3922,
#  3936,
#  3937,
#  3938,
#  3939,
#  3944,
#  3945,
#  3956,
#  3957,
#  3959,
#  3965,
#  3974,
#  3976,
#  3983,
#  3989,
#  3997,
#  3998,
#  3999,
#  4004,
#  4008,
#  4009,
#  4013,
#  4014,
#  4021,
#  4022,
#  4028,
#  4029,
#  4031,
#  4039,
#  4040,
#  4041,
#  4049,
#  4059,
#  4061,
#  4066,
#  4072,
#  4088,
#  4095,
#  4099,
#  4104,
#  4105,
#  4106,
#  4109,
#  4110,
#  4113,
#  4115,
#  4116,
#  4120,
#  4122,
#  4128,
#  4129,
#  4133,
#  4137,
#  4140,
#  4142,
#  4145,
#  4147,
#  4151,
#  4171,
#  4172,
#  4177,
#  4181,
#  4184,
#  4186,
#  4191,
#  4192,
#  4194,
#  4202,
#  4208,
#  4210,
#  4212,
#  4213,
#  4214,
#  ...]

# %%
left_overs = list(set(range(len(Obj.pcd.points)))-set(all_dilated))
border_left_overs = left_overs+dilated_border

# %%
border_left_overs
# Out:
# [38,
#  88,
#  107,
#  127,
#  128,
#  135,
#  136,
#  143,
#  146,
#  210,
#  214,
#  227,
#  251,
#  262,
#  268,
#  309,
#  313,
#  325,
#  329,
#  340,
#  342,
#  351,
#  369,
#  379,
#  385,
#  387,
#  388,
#  402,
#  405,
#  415,
#  435,
#  444,
#  463,
#  487,
#  490,
#  493,
#  497,
#  511,
#  515,
#  518,
#  524,
#  525,
#  533,
#  553,
#  559,
#  566,
#  573,
#  603,
#  629,
#  631,
#  634,
#  641,
#  645,
#  655,
#  672,
#  682,
#  702,
#  720,
#  721,
#  731,
#  735,
#  749,
#  762,
#  765,
#  768,
#  769,
#  770,
#  784,
#  786,
#  791,
#  796,
#  801,
#  809,
#  825,
#  833,
#  838,
#  841,
#  844,
#  848,
#  851,
#  882,
#  887,
#  895,
#  913,
#  914,
#  919,
#  928,
#  939,
#  946,
#  948,
#  955,
#  964,
#  967,
#  968,
#  986,
#  988,
#  989,
#  990,
#  1004,
#  1006,
#  1022,
#  1030,
#  1045,
#  1058,
#  1061,
#  1068,
#  1100,
#  1102,
#  1107,
#  1112,
#  1117,
#  1135,
#  1140,
#  1151,
#  1153,
#  1158,
#  1161,
#  1164,
#  1165,
#  1169,
#  1172,
#  1179,
#  1195,
#  1197,
#  1203,
#  1215,
#  1220,
#  1226,
#  1228,
#  1231,
#  1238,
#  1241,
#  1255,
#  1258,
#  1271,
#  1286,
#  1299,
#  1300,
#  1308,
#  1318,
#  1347,
#  1361,
#  1378,
#  1399,
#  1404,
#  1407,
#  1420,
#  1426,
#  1428,
#  1429,
#  1436,
#  1437,
#  1442,
#  1450,
#  1454,
#  1464,
#  1468,
#  1482,
#  1483,
#  1490,
#  1491,
#  1493,
#  1511,
#  1514,
#  1516,
#  1524,
#  1525,
#  1539,
#  1547,
#  1553,
#  1566,
#  1570,
#  1571,
#  1572,
#  1588,
#  1591,
#  1599,
#  1610,
#  1618,
#  1627,
#  1628,
#  1634,
#  1652,
#  1665,
#  1683,
#  1698,
#  1703,
#  1722,
#  1723,
#  1726,
#  1735,
#  1736,
#  1738,
#  1749,
#  1769,
#  1782,
#  1783,
#  1790,
#  1806,
#  1832,
#  1833,
#  1838,
#  1844,
#  1870,
#  1873,
#  1899,
#  1903,
#  1917,
#  1920,
#  1925,
#  1927,
#  1949,
#  1954,
#  1958,
#  1972,
#  1976,
#  1990,
#  2000,
#  2003,
#  2006,
#  2010,
#  2016,
#  2025,
#  2035,
#  2036,
#  2037,
#  2038,
#  2055,
#  2076,
#  2085,
#  2088,
#  2106,
#  2108,
#  2122,
#  2132,
#  2134,
#  2154,
#  2164,
#  2166,
#  2169,
#  2185,
#  2196,
#  2220,
#  2231,
#  2238,
#  2251,
#  2253,
#  2279,
#  2280,
#  2281,
#  2307,
#  2314,
#  2321,
#  2323,
#  2327,
#  2339,
#  2347,
#  2363,
#  2390,
#  2396,
#  2398,
#  2399,
#  2400,
#  2407,
#  2414,
#  2426,
#  2429,
#  2434,
#  2442,
#  2449,
#  2451,
#  2453,
#  2454,
#  2464,
#  2466,
#  2485,
#  2499,
#  2501,
#  2502,
#  2507,
#  2513,
#  2515,
#  2518,
#  2520,
#  2530,
#  2545,
#  2547,
#  2552,
#  2559,
#  2575,
#  2581,
#  2590,
#  2592,
#  2596,
#  2606,
#  2613,
#  2615,
#  2620,
#  2632,
#  2641,
#  2650,
#  2662,
#  2667,
#  2676,
#  2688,
#  2689,
#  2693,
#  2700,
#  2706,
#  2712,
#  2729,
#  2734,
#  2738,
#  2755,
#  2762,
#  2771,
#  2774,
#  2781,
#  2787,
#  2801,
#  2808,
#  2812,
#  2816,
#  2817,
#  2821,
#  2826,
#  2829,
#  2830,
#  2833,
#  2853,
#  2859,
#  2866,
#  2870,
#  2885,
#  2897,
#  2902,
#  2910,
#  2918,
#  2930,
#  2935,
#  2944,
#  2951,
#  2958,
#  2960,
#  2975,
#  2979,
#  2980,
#  2986,
#  2988,
#  3008,
#  3012,
#  3024,
#  3034,
#  3039,
#  3040,
#  3051,
#  3054,
#  3057,
#  3063,
#  3067,
#  3068,
#  3070,
#  3077,
#  3083,
#  3084,
#  3090,
#  3098,
#  3103,
#  3108,
#  3116,
#  3117,
#  3139,
#  3142,
#  3145,
#  3151,
#  3152,
#  3158,
#  3163,
#  3167,
#  3171,
#  3172,
#  3183,
#  3193,
#  3204,
#  3206,
#  3208,
#  3209,
#  3211,
#  3217,
#  3223,
#  3229,
#  3232,
#  3234,
#  3244,
#  3246,
#  3256,
#  3271,
#  3277,
#  3280,
#  3281,
#  3292,
#  3303,
#  3304,
#  3312,
#  3313,
#  3316,
#  3317,
#  3327,
#  3330,
#  3335,
#  3349,
#  3354,
#  3366,
#  3373,
#  3382,
#  3385,
#  3390,
#  3391,
#  3392,
#  3406,
#  3421,
#  3422,
#  3448,
#  3466,
#  3468,
#  3472,
#  3475,
#  3480,
#  3490,
#  3492,
#  3494,
#  3495,
#  3499,
#  3505,
#  3511,
#  3512,
#  3513,
#  3545,
#  3554,
#  3562,
#  3569,
#  3570,
#  3582,
#  3587,
#  3591,
#  3604,
#  3620,
#  3632,
#  3636,
#  3641,
#  3648,
#  3655,
#  3656,
#  3669,
#  3673,
#  3674,
#  3682,
#  3685,
#  3692,
#  3699,
#  3703,
#  3704,
#  3706,
#  3707,
#  3711,
#  3716,
#  3724,
#  3738,
#  3741,
#  3747,
#  3755,
#  3768,
#  3774,
#  3802,
#  3805,
#  3806,
#  3812,
#  3814,
#  3816,
#  3819,
#  3823,
#  3825,
#  3838,
#  3845,
#  3847,
#  3851,
#  3859,
#  3882,
#  3891,
#  3894,
#  3895,
#  3902,
#  3903,
#  3918,
#  3927,
#  3935,
#  3947,
#  3948,
#  3949,
#  3960,
#  3962,
#  3968,
#  3986,
#  3987,
#  4001,
#  4003,
#  4030,
#  4032,
#  4043,
#  4050,
#  4051,
#  4056,
#  4058,
#  4065,
#  4073,
#  4080,
#  4092,
#  4098,
#  4101,
#  4112,
#  4119,
#  4130,
#  4143,
#  4152,
#  4158,
#  4159,
#  4162,
#  4173,
#  4185,
#  4188,
#  4190,
#  4204,
#  4205,
#  4217,
#  4221,
#  4225,
#  4237,
#  4241,
#  4255,
#  4258,
#  4266,
#  4269,
#  4272,
#  4286,
#  4295,
#  4304,
#  4306,
#  4313,
#  4314,
#  4318,
#  4333,
#  4338,
#  4350,
#  4351,
#  4353,
#  4357,
#  4359,
#  4370,
#  4373,
#  4384,
#  4392,
#  4396,
#  4398,
#  4401,
#  4408,
#  4415,
#  4424,
#  4429,
#  4430,
#  4432,
#  4439,
#  4449,
#  4454,
#  4455,
#  4464,
#  4465,
#  4466,
#  4480,
#  4481,
#  4487,
#  4490,
#  4493,
#  4496,
#  4511,
#  4515,
#  4516,
#  4560,
#  4569,
#  4572,
#  4575,
#  4576,
#  4578,
#  4579,
#  4584,
#  4585,
#  4586,
#  4587,
#  4611,
#  4614,
#  4623,
#  4630,
#  4658,
#  4665,
#  4666,
#  4669,
#  4672,
#  4677,
#  4678,
#  4682,
#  4689,
#  4692,
#  4706,
#  4712,
#  4715,
#  4718,
#  4721,
#  4733,
#  4746,
#  4749,
#  4750,
#  4751,
#  4770,
#  4773,
#  4777,
#  4799,
#  4800,
#  4803,
#  4815,
#  4818,
#  4820,
#  4825,
#  4826,
#  4832,
#  4838,
#  4839,
#  4855,
#  4863,
#  4868,
#  4875,
#  4882,
#  4887,
#  4907,
#  4921,
#  4922,
#  4927,
#  4928,
#  4932,
#  4937,
#  4942,
#  4943,
#  4944,
#  4953,
#  4967,
#  4969,
#  4972,
#  4974,
#  4999,
#  5016,
#  5028,
#  5029,
#  5033,
#  5035,
#  5042,
#  5044,
#  5045,
#  5051,
#  5060,
#  5064,
#  5073,
#  5074,
#  5084,
#  5099,
#  5111,
#  5115,
#  5116,
#  5120,
#  5124,
#  5129,
#  5135,
#  5138,
#  5145,
#  5148,
#  5155,
#  5163,
#  5166,
#  5169,
#  5173,
#  5179,
#  5196,
#  5209,
#  5216,
#  5222,
#  5229,
#  5231,
#  5240,
#  5251,
#  5254,
#  5269,
#  5273,
#  5274,
#  5277,
#  5278,
#  5283,
#  5284,
#  5288,
#  5295,
#  5296,
#  5301,
#  5303,
#  5307,
#  5308,
#  5310,
#  5314,
#  5318,
#  5319,
#  5330,
#  5335,
#  5348,
#  5357,
#  5387,
#  5394,
#  5396,
#  5400,
#  5402,
#  5413,
#  5414,
#  5416,
#  5424,
#  5437,
#  5473,
#  5478,
#  5480,
#  5487,
#  5489,
#  5495,
#  5500,
#  5506,
#  5512,
#  5524,
#  5535,
#  5537,
#  5560,
#  5567,
#  5573,
#  5576,
#  5578,
#  5580,
#  5581,
#  5583,
#  5587,
#  5588,
#  5595,
#  5605,
#  5614,
#  5635,
#  5644,
#  5647,
#  5651,
#  5660,
#  5667,
#  5671,
#  5672,
#  5685,
#  5687,
#  5695,
#  5701,
#  5708,
#  5711,
#  5712,
#  5717,
#  5735,
#  5739,
#  5741,
#  5754,
#  5766,
#  5767,
#  5769,
#  5770,
#  5774,
#  5778,
#  5782,
#  5790,
#  5804,
#  5809,
#  5811,
#  5812,
#  5816,
#  5828,
#  5834,
#  5839,
#  5840,
#  5847,
#  5863,
#  5876,
#  5892,
#  5894,
#  5897,
#  5900,
#  5912,
#  5919,
#  5920,
#  5921,
#  5930,
#  5931,
#  5932,
#  5933,
#  5937,
#  5940,
#  5943,
#  5945,
#  5947,
#  5951,
#  5957,
#  5958,
#  5960,
#  5961,
#  5965,
#  5980,
#  5983,
#  5987,
#  5994,
#  5999,
#  6000,
#  6006,
#  6011,
#  6033,
#  6036,
#  6055,
#  6057,
#  6064,
#  6069,
#  6070,
#  6075,
#  6078,
#  6092,
#  6095,
#  6099,
#  6100,
#  6102,
#  6107,
#  6108,
#  6109,
#  6110,
#  6111,
#  6122,
#  6131,
#  6136,
#  6141,
#  6151,
#  6161,
#  6167,
#  6170,
#  6183,
#  6203,
#  6208,
#  6210,
#  6211,
#  6231,
#  6233,
#  6244,
#  6251,
#  6252,
#  6254,
#  6256,
#  6259,
#  6277,
#  6278,
#  6285,
#  6289,
#  6291,
#  6293,
#  6298,
#  6306,
#  6314,
#  6317,
#  6320,
#  6328,
#  6337,
#  6340,
#  6348,
#  6353,
#  6364,
#  6384,
#  6386,
#  6387,
#  6389,
#  6392,
#  6393,
#  6394,
#  6395,
#  6399,
#  6405,
#  6408,
#  6415,
#  6435,
#  6442,
#  6452,
#  6454,
#  6456,
#  6459,
#  6465,
#  6467,
#  6472,
#  6474,
#  6481,
#  6482,
#  6484,
#  6486,
#  6493,
#  6494,
#  6498,
#  6499,
#  6501,
#  6513,
#  6514,
#  6515,
#  6516,
#  6517,
#  6518,
#  6520,
#  6522,
#  6531,
#  6537,
#  6543,
#  6556,
#  6560,
#  6564,
#  6568,
#  6573,
#  6575,
#  6578,
#  6583,
#  6584,
#  6592,
#  6597,
#  6609,
#  6615,
#  6617,
#  6620,
#  6630,
#  6632,
#  6633,
#  6634,
#  6640,
#  6642,
#  6645,
#  6647,
#  6653,
#  6658,
#  6660,
#  6667,
#  6668,
#  6669,
#  6672,
#  6674,
#  6675,
#  6682,
#  6683,
#  6685,
#  6696,
#  6697,
#  6698,
#  6701,
#  6702,
#  6706,
#  6708,
#  6709,
#  6710,
#  6714,
#  6718,
#  6719,
#  6721,
#  6723,
#  6724,
#  6730,
#  6731,
#  6732,
#  6733,
#  6736,
#  6737,
#  6742,
#  6743,
#  6746,
#  6748,
#  6749,
#  6758,
#  6765,
#  6774,
#  6775,
#  6776,
#  6777,
#  6778,
#  6779,
#  6788,
#  6792,
#  6796,
#  6802,
#  6822,
#  6827,
#  6832,
#  ...]

# %%
from copy import deepcopy
def knn_expand(Obj,my_borders,node_face,face_nodes,size):
    borders = deepcopy(my_borders)
    face_nodes_new = deepcopy(face_nodes)
    tree = o3d.geometry.KDTreeFlann(Obj.pcd)
    no_change = 0
    while borders:
        len_before = len(borders)
        
        idx = borders.pop(0)
        point = Obj.pcd.points[idx]
        [k, q_idxs, _] = tree.search_knn_vector_3d(point, size)
        #vote 
        my_faces = {}
        for q_idx in q_idxs:
            if q_idx not in node_face:
                continue
                
            if node_face[q_idx] not in my_faces:
                my_faces[node_face[q_idx]] = 1
            else:
                my_faces[node_face[q_idx]] += 1
                
        if len(my_faces)==0:
            borders.append(idx)
        else:
            winner = max(my_faces, key=my_faces.get)
            face_nodes_new[winner].add(idx)
            node_face[idx] = winner
            
        if len(borders) == len_before:
            no_change += 1
        else:
            no_change = 0
        
        if no_change >= len_before+10000000:
            break
    print(len(borders))
    return face_nodes_new

# %%
expanded_faces = knn_expand(Obj,border_left_overs,node_face,face_nodes,size=5)
# Out:
# 0

# %%
for expanded_face,(_,dilated_face) in zip(expanded_faces,dilated_faces):
    print(len(expanded_face),len(dilated_face))
# Out:
# 7065 5687
# 6078 4818
# 3197 2198
# 3943 2117
# 2887 1944
# 1996 1493
# 1701 1270
# 1660 1009
# 604 291
# 691 284

# %%
import open3d as o3d
import numpy as np
colors = [(0,255,0) for _ in Obj.pcd.points]
for face in expanded_faces:
    color = tuple(random.choices(range(256), k=3))
    for point in face:
        colors[point] = color
Obj.pcd.colors = o3d.utility.Vector3dVector(np.asarray(colors).astype(np.float) / 255.0)
o3d.visualization.draw_geometries([Obj.pcd])
# Out:
# C:\Users\alial\AppData\Local\Temp\ipykernel_17824\662944009.py:8: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Obj.pcd.colors = o3d.utility.Vector3dVector(np.asarray(colors).astype(np.float) / 255.0)

# %% [markdown]
# <h3> END

# %%
def dilate(my_obj,size,thre):
    tmp_Obj = copy(my_obj)
    pcd_tree = o3d.geometry.KDTreeFlann(tmp_Obj.pcd)
    w_co = copy(OG_W_co)
    for i in range(len(Obj.pcd.points)):
        point = Obj.pcd.points[i]
        if Obj.w_co[i] < thre :
            [k, idx, _] = pcd_tree.search_knn_vector_3d(point, size)
            w_co[idx] = max(OG_W_co[idx])
    return w_co

# %%
def erode(OG_W_co,size,thre):
    pcd_tree = o3d.geometry.KDTreeFlann(Obj.pcd)
    w_co = copy(OG_W_co)
    for i in range(len(Obj.pcd.points)):
        point = Obj.pcd.points[i]
        if Obj.w_co[i] < thre :
            [k, idx, _] = pcd_tree.search_knn_vector_3d(point, size)
            w_co[idx] = min(OG_W_co[idx])
    return w_co

# %%
koko_w_co_erode = erode(Obj.w_co,50,0.9)

# %%
koko_w_co_dilate = dilate(koko_w_co,50,0.9)

# %%
faces = get_sides(graph,Obj.w_co,0.)

# %%
koko_faces = get_sides(graph,koko_w_co,0.9)

# %%
sizes = [size for size,_ in faces]
print(sizes)

# %%
sizes = [size for size,_ in koko_faces]
print(sizes)

# %%
faces

# %%
import open3d as o3d
import numpy as np
colors = [(0,255,0) for _ in Obj.pcd.points]
for size,face in faces:
    color = tuple(random.choices(range(256), k=3))
    for point in face:
        colors[point] = color
Obj.pcd.colors = o3d.utility.Vector3dVector(np.asarray(colors).astype(np.float) / 255.0)
o3d.visualization.draw_geometries([Obj.pcd])
# Out:
# C:\Users\alial\AppData\Local\Temp\ipykernel_14308\2493254240.py:8: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   Obj.pcd.colors = o3d.utility.Vector3dVector(np.asarray(colors).astype(np.float) / 255.0)

# %%
import open3d as o3d
import numpy as np
colors = [(0,255,0) for _ in Obj.pcd.points]
for size,face in koko_faces:
    color = tuple(random.choices(range(256), k=3))
    for point in face:
        colors[point] = color
Obj.pcd.colors = o3d.utility.Vector3dVector(np.asarray(colors).astype(np.float) / 255.0)
o3d.visualization.draw_geometries([Obj.pcd])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 4>()
#       2 import numpy as np
#       3 colors = [(0,255,0) for _ in Obj.pcd.points]
# ----> 4 for size,face in koko_faces:
#       5     color = tuple(random.choices(range(256), k=3))
#       6     for point in face:
#
# NameError: name 'koko_faces' is not defined

# %%
import random
def get_sides(Graph, w_co,thre):
    faces = []
    all_visited = set()
    nodes = list(Graph.nodes)
    while len(nodes):
        random_point = nodes.pop(0)
        while random_point in all_visited:
            if not len(nodes):
                sorted_faces = sorted(faces,key = lambda key:key[0], reverse = True)
                return sorted_faces[:10]
            random_point = nodes.pop(0)
       
        queue = [random_point]
        visited = set()
        while len(queue):
            point = queue.pop(0)
            if point not in visited:
                visited.add(point)
                all_visited.add(point)
                neighbors = Graph.neighbors(point)
                for neighbor in neighbors:
                    all_visited.add(neighbor)
                    if w_co[neighbor] > thre:
                        queue.append(neighbor)
        faces.append((len(visited),visited))
    sorted_faces = sorted(faces,key = lambda key:key[0], reverse = True)
    return sorted_faces[:20]

# %%
from copy import copy,deepcopy

# %%
graph = deepcopy(pruned_graph)
# graph.remove_nodes_from(border_nodes)
# graph.remove_nodes_from(removed_nodes)

# %%
faces = get_sides(graph,NormalizeData(Obj.w_co),0.92)

# %%
import open3d as o3d
import numpy as np
colors = [(0,255,0) for _ in Obj.pcd.points]
for size,face in faces:
    color = tuple(random.choices(range(256), k=3))
    for point in face:
        colors[point] = color
Obj.pcd.colors = o3d.utility.Vector3dVector(np.asarray(colors).astype(np.float) / 255.0)
o3d.visualization.draw_geometries([Obj.pcd])

# %%
shortest_cycle_length = np.sqrt(len(Obj.pcd.points))//t1
smallest_isolated_island_length = np.sqrt(len(Obj.pcd.points))//t2
shortest_allowed_branch_length = np.sqrt(len(Obj.pcd.points))//t3

# %%
isolated_islands_pruned_graph, F_lines, isolated_islands = helper.create_graph(Obj,\
2,shortest_cycle_length, smallest_isolated_island_length)
print("After graph",len([point for branch in F_lines for point in branch]))

# %%
pruned_graph, removed_nodes, valid_nodes = helper.prune_branches(F_lines,isolated_islands_pruned_graph,\
shortest_allowed_branch_length)
Obj.pruned_graph = pruned_graph
print("After Pruning",len([node for branch in valid_nodes for node in branch]))

# %%
border_nodes = []
for idx,value in enumerate(Obj.w_co):
    if value<0.98:
        border_nodes.append(idx)

# %%
border_nodes

# %%
import open3d as o3d
import numpy as np
colors = [(0,255,0) for _ in Obj.pcd.points]
for idx in border_nodes:
    color = (255,0,0)
    colors[idx] = color
Obj.pcd.colors = o3d.utility.Vector3dVector(np.asarray(colors).astype(np.float) / 255.0)
o3d.visualization.draw_geometries([Obj.pcd])

# %%
import random
def get_sides(Graph, w_co, thre):
    faces = []
    all_visited = set()
    nodes = list(Graph.nodes)
    while len(nodes):
        random_point = nodes.pop(0)
        while random_point in all_visited:
            if not len(nodes):
                sorted_faces = sorted(faces,key = lambda key:key[0], reverse = True)
                return sorted_faces[:10]
            random_point = nodes.pop(0)
       
        queue = [random_point]
        visited = set()
        while len(queue):
            point = queue.pop(0)
            if point not in visited:
                visited.add(point)
                all_visited.add(point)
                neighbors = Graph.neighbors(point)
                for neighbor in neighbors:
                    all_visited.add(neighbor)
                    if w_co[neighbor]>thre:
                        queue.append(neighbor)
        faces.append((len(visited),visited))
    sorted_faces = sorted(faces,key = lambda key:key[0], reverse = True)
    return sorted_faces[:20]

# %%
faces = get_sides(pruned_graph,Obj.w_co, 0.93)

# %%
faces

# %%
def cut_faces(Graph,w_co,thre,faces):
    
    nodes = list(set(Graph.nodes)-set([node for _,face in faces for node in face]))
    nodes_values = w_co[nodes]
    arr1inds = nodes_values.argsort()
    nodes = list(np.asarray(nodes)[arr1inds[::-1]])
    momentum = thre
    borders = []
    queue = []
    all_visited = set()
    while(len(nodes)):
        node = nodes.pop(0)
        queue.append(node)
        visited = []
        momentum = thre
        while len(queue):
            curr_node = queue.pop(0)
            if curr_node not in all_visited:
                all_visited.add(curr_node)
                visited.append(curr_node)
                neighbors = Graph.neighbors(curr_node)
                for neighbor in neighbors:
                    if w_co[neighbor]<=momentum and neighbor not in all_visited:
                        print(momentum)
                        queue.append(neighbor)
                    momentum = (momentum + 0.000001*(momentum-w_co[neighbor]))
        borders.append(visited)
    return borders

# %%
borders = cut_faces(pruned_graph,Obj.w_co, 0.93,faces)

# %%
set_borders = set([node for border in borders for node in border])
filtred_faces = [(size,set(face)-set_borders) for size,face in faces]

# %%
filtred_faces

# %%
faces

# %%
import numpy as np

def NormalizeData(data):
    return (data - np.min(data)) / (np.max(data) - np.min(data))

# %%
w =NormalizeData( 0.2 *Obj.w_k + 0.8*Obj.w_co)

# %%
Obj.init_create_crease(0.8, 2,2,2)

# %%
Obj.create_crease(1.2,2,2)

# %%
w = NormalizeData(Obj.w_co+Obj.w_b2+Obj.w_k)

# %%
Obj.show_heat(w)

# %%
filtred_faces

# %%
len(Obj.pcd.points)

# %%
import open3d as o3d
import numpy as np
colors = [(0,255,0) for _ in Obj.pcd.points]
for size,face in faces:
    color = tuple(random.choices(range(256), k=3))
    for point in face:
        colors[point] = color
Obj.pcd.colors = o3d.utility.Vector3dVector(np.asarray(colors).astype(np.float) / 255.0)
o3d.visualization.draw_geometries([Obj.pcd])

# %%
import open3d as o3d
import numpy as np
colors = [(0,255,0) for _ in Obj.pcd.points]
for size,face in filtred_faces:
    color = tuple(random.choices(range(256), k=3))
    for point in face:
        colors[point] = color
Obj.pcd.colors = o3d.utility.Vector3dVector(np.asarray(colors).astype(np.float) / 255.0)
o3d.visualization.draw_geometries([Obj.pcd])

# %% [markdown]
# <h1> trying to segement </h1>

# %%
valid = []
colors = [(0,255,0) for _ in Obj.pcd.points]
for idx,val in enumerate(w):
    if Obj.w_co[idx]<0.85:
        colors[idx] = (255,0,0)
    if Obj.w_k[idx] < 0.85 and Obj.w_co[idx]>=0.85:
        colors[idx] = (0,0,255)
Obj.pcd.colors = o3d.utility.Vector3dVector(np.asarray(colors).astype(np.float) / 255.0)
o3d.visualization.draw_geometries([Obj.pcd])

# %%
import matplotlib
import open3d as o3d
def show_heat(weights,thre = 0):
    if len(weights.shape)>1 and weights.shape[-1] > 1:
        weights = 1-NormalizeData(np.sqrt(np.sum(weights * weights,axis=1)))
    weights = weights.copy()
    # weights[weights>=thre] = 1
    cmap = matplotlib.cm.get_cmap('viridis')
    rgba = cmap(weights)
    rgb = rgba[:,:3]

    Obj.pcd.colors = o3d.utility.Vector3dVector(np.asarray(rgb).astype(np.float))
    o3d.visualization.draw_geometries([Obj.pcd])

# %%
len(Obj.w_co.shape)

# %%
show_heat(Obj.w_co)

# %%
Obj.w_cr_v.shape[-1]

# %%
faces = get_sides(Obj.pruned_graph, Obj.w_co, 0.96)
